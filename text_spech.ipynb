# %%
# !pip install gtts

# %%
#instalar a biblioteca gTTS !pip install gTTS

from gtts import gTTS

text_to_say = "How are you doing?."

language = "en"

gtts_object = gTTS(text = text_to_say,
                  lang = language,
                  slow = False)

gtts_object.save("/content/gtts.wav")

from IPython.display import Audio

Audio("/content/gtts.wav")

portuguese_text = "Como você está"

portuguese_language = "pt"

french_gtts_object = gTTS(text = portuguese_text,
                          lang = portuguese_language,
                          slow = True)

french_gtts_object.save("/content/portuguese.wav")

Audio("/content/portuguese.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
